# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://fr.m.wikipedia.org/wiki/Wikipédia:Accueil_principal'

# %%
# Fonction permettant d'afficher et de parser le contenu html de la page 

def get_n_parse(url):
    page = requests.get(url)
    content = BeautifulSoup(page.content,'html.parser')
    return content

# Fontion qui permet d'afficher le titre de l'article de la page d'accueil de wikipedia

def get_article_title(url):
    page = requests.get(url)
    content = BeautifulSoup(page.content,'html.parser')
    title = content.find('b').text
    return title
    
get_article_title(url)
# Out:
# 'Charles Spencer Chaplin'

# %%
# Une fonction qui nous permet de recueillir le titre et le contenu du sommaire de la page python programming langage dans un dictionnaire de donnees

def get_title_value():
    link = 'https://en.wikipedia.org/wiki/Python_(programming_language)'
    page = requests.get(link)
    soup = BeautifulSoup(page.text,'html.parser')
    tbody = soup.find('tbody')
    title = tbody.find_all('th')
    t_value = tbody.find_all('td',{'class':['infobox-data','infobox-full-data']})
    my_dict ={'Titres':[],'Elements':[]}
    for i in range(len(t_value)):
        if t_value[i].text != '':
            my_dict['Elements'].append(t_value[i].text)
    for j in range(len(title)):
            my_dict['Titres'].append(title[j].get_text())
    return my_dict
            
get_title_value()
# Out:
# {'Titres': ['Paradigm',
#   'Designed\xa0by',
#   'Developer',
#   'First\xa0appeared',
#   'Stable release',
#   'Preview release',
#   'Typing discipline',
#   'OS',
#   'License',
#   'Filename extensions',
#   'Website',
#   'Major implementations',
#   'Dialects',
#   'Influenced by',
#   'Influenced'],
#  'Elements': ['Multi-paradigm: object-oriented,[1] procedural (imperative), functional, structured, reflective',
#   'Guido van Rossum',
#   'Python Software Foundation',
#   '20\xa0February 1991; 32 years ago\xa0(1991-02-20)[2]',
#   '3.11.4[3]\xa0\n   / 7 June 2023; 42 days ago\xa0(7 June 2023)',
#   '3.12.0b4[4]\xa0\n   / 11 July 2023; 8 days ago\xa0(11 July 2023)',
#   'Duck, dynamic, strong typing;[5] gradual (since 3.5, but ignored in CPython)[6]',
#   'Windows, macOS, Linux/UNIX, Android[7][8] and more[9]',
#   'Python Software Foundation License',
#   '.py, .pyi, .pyc, .pyd, .pyw, .pyz (since 3.5),[10] .pyo (prior to 3.5)[11]',
#   'python.org',
# ...

# %%
# Une fonction qui permet de recuperer tous les liens d'une page wikipedia 

def get_page_links(url):
    page = requests.get(url)
    soup = BeautifulSoup(page.text,'html.parser')
    link1 = soup.find_all('link')
    link2 = soup.find_all('a')
    links = link1 + link2
    for link in links:
        if link['href'][0] != 'h':
            print('https://fr.wikipedia.org' + link['href'])
        else:
            print(link['href'])
get_page_links(url)
# Out:
# https://fr.wikipedia.org/w/load.php?lang=fr&modules=ext.discussionTools.init.styles%7Cext.wikimediaBadges%7Cmediawiki.hlist%7Cmediawiki.ui.button%2Cicon%7Cmediawiki.widgets.styles%7Cmobile.init.styles%7Coojs-ui-core.icons%2Cstyles%7Coojs-ui.styles.indicators%7Cskins.minerva.base.styles%7Cskins.minerva.content.styles.images%7Cskins.minerva.icons.wikimedia%7Cskins.minerva.mainMenu.icons%2Cstyles%7Cskins.minerva.mainPage.styles%7Cskins.minerva.messageBox.styles%7Cwikibase.client.init&only=styles&skin=minerva
# https://fr.wikipedia.org//upload.wikimedia.org
# https://fr.wikipedia.org/w/api.php?action=webapp-manifest
# https://fr.wikipedia.org/w/api.php?action=featuredfeed&feed=potd&feedformat=atom
# https://fr.wikipedia.org/w/api.php?action=featuredfeed&feed=featured&feedformat=atom
# https://fr.wikipedia.org/w/api.php?action=featuredfeed&feed=raw&feedformat=atom
# https://fr.wikipedia.org/w/api.php?action=featuredfeed&feed=wikimag&feedformat=atom
# ...

# %%
# Regroupons les precedentes fonctions dans une fonction principale

def general_function(url):
    getNParse = get_n_parse(url)
    getATitle = get_article_title(url)
    print (f"Tous les liens de la page ci-dessus: \n{get_page_links(url)}\n\n\nLe contenu HTML de la page: \n{getNParse}\n\n\nL'article de la page: \n{getATitle}\n\n")

# %%
# Testons la fonction dans une page wikipedia de notre choix

url = 'https://en.wikipedia.org/wiki/Main_Page'
general_function(url)
# Out:
# https://fr.wikipedia.org/w/load.php?lang=en&modules=codex-search-styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cskins.vector.icons%2Cstyles&only=styles&skin=vector-2022
# https://fr.wikipedia.org/w/load.php?lang=en&modules=site.styles&only=styles&skin=vector-2022
# https://fr.wikipedia.org//upload.wikimedia.org
# https://fr.wikipedia.org//en.m.wikipedia.org/wiki/Main_Page
# https://fr.wikipedia.org/w/api.php?action=featuredfeed&feed=potd&feedformat=atom
# https://fr.wikipedia.org/w/api.php?action=featuredfeed&feed=featured&feedformat=atom
# https://fr.wikipedia.org/w/api.php?action=featuredfeed&feed=onthisday&feedformat=atom
# https://fr.wikipedia.org/static/apple-touch/wikipedia.png
# https://fr.wikipedia.org/static/favicon/wikipedia.ico
# https://fr.wikipedia.org/w/opensearch_desc.php
# https://fr.wikipedia.org//en.wikipedia.org/w/api.php?action=rsd
# https://en.wikipedia.org/wiki/Main_Page
# ...

# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
